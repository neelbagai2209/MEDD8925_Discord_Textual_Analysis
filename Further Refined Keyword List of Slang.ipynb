# %%
import pandas as pd
import re

# %%
# Replace with your actual file path
df = pd.read_csv('refined_classified_keywords.csv')
df.head()
# Out:
#       type  freq_tar  range_tar  likelihood  effect     word    category  \
# 0     like   1137753        735   16296.168   0.011     LIKE  ADJECTIVES
# 1       im   1099153        736   15741.881   0.010      NaN         NaN
# 2  welcome    784070        729   11221.085   0.007  WELCOME  ADJECTIVES
# 3      get    624800        736    8938.409   0.006      GET       VERBS
# 4       oh    607688        734    8693.258   0.006       OH       NOUNS
#
#      subcategory
# 0        ADJ.ALL
# 1            NaN
# 2        ADJ.ALL
# 3      VERB.BODY
# 4  NOUN.LOCATION

# %%
# Keep if subcategory is 'NOUN.COMMUNICATION' or blank/NaN
mask = (df['subcategory'] == 'NOUN.COMMUNICATION') | (df['subcategory'].isnull()) | (df['subcategory'] == '')
filtered_df = df[mask].copy()
filtered_df.head()
# Out:
#     type  freq_tar  range_tar  likelihood  effect word category  \
# 1     im   1099153        736   15741.881   0.010  NaN      NaN
# 6    yes    542445        734    7758.750   0.005  YES    NOUNS
# 7   dont    517848        735    7406.509   0.005  NaN      NaN
# 11    hi    442385        732    6326.092   0.004   HI    NOUNS
# 14   got    404171        736    5779.120   0.004  NaN      NaN
#
#            subcategory
# 1                  NaN
# 6   NOUN.COMMUNICATION
# 7                  NaN
# 11  NOUN.COMMUNICATION
# 14                 NaN

# %%
def canonicalize_type(word):
    word = str(word).lower()
    # Remove leading 'n' if followed by 'bruh' or 'good'
    word = re.sub(r'^n(bruh|good)$', r'\1', word)
    # Remove trailing 'n' if preceded by 'bruh' or 'good'
    word = re.sub(r'^(bruh|good)n$', r'\1', word)
    return word

filtered_df['canonical_type'] = filtered_df['type'].apply(canonicalize_type)
filtered_df.head(10)
# Out:
#      type  freq_tar  range_tar  likelihood  effect   word category  \
# 1      im   1099153        736   15741.881   0.010    NaN      NaN
# 6     yes    542445        734    7758.750   0.005    YES    NOUNS
# 7    dont    517848        735    7406.509   0.005    NaN      NaN
# 11     hi    442385        732    6326.092   0.004     HI    NOUNS
# 14    got    404171        736    5779.120   0.004    NaN      NaN
# 19   guys    319615        732    4569.182   0.003    NaN      NaN
# 25    hey    293683        735    4198.208   0.003    NaN      NaN
# 27  wanna    292759        734    4184.990   0.003    NaN      NaN
# 34  gonna    237783        733    3398.675   0.002    NaN      NaN
# 36  hello    235588        735    3367.284   0.002  HELLO    NOUNS
#
#            subcategory canonical_type
# 1                  NaN             im
# 6   NOUN.COMMUNICATION            yes
# 7                  NaN           dont
# 11  NOUN.COMMUNICATION             hi
# 14                 NaN            got
# 19                 NaN           guys
# 25                 NaN            hey
# 27                 NaN          wanna
# 34                 NaN          gonna
# 36  NOUN.COMMUNICATION          hello

# %%
# If your numeric columns differ, adjust the list below
agg_dict = {
    'freq_tar': 'sum',
    'range_tar': 'sum',
    'likelihood': 'sum',
    'effect': 'sum',
    'type': 'first',
    'word': 'first',
    'category': 'first',
    'subcategory': 'first'
    # Add any additional columns you wish to keep
}

# Group by canonical_type
result_df = filtered_df.groupby('canonical_type', as_index=False).agg(agg_dict)
result_df.head(10)
# Out:
#   canonical_type  freq_tar  range_tar  likelihood  effect      type    word  \
# 0             aa      3840        682      54.856     0.0        aa      AA
# 1           aaah      1598        494      22.828     0.0      aaah    None
# 2         aaahhh      2419        242      34.556     0.0    aaahhh    None
# 3         aboutn      4795        685      68.499     0.0    aboutn    None
# 4            abs      2981        566      42.585     0.0       abs    None
# 5            abt     21268        709     303.835     0.0       abt    None
# 6        abusing      2415        621      34.499     0.0   abusing    None
# 7         accent      7601        702     108.584     0.0    accent  ACCENT
# 8       accountn      2200        578      31.428     0.0  accountn    None
# 9       accounts      4888        695      69.827     0.0  accounts    None
#
#   category         subcategory
# 0    NOUNS  NOUN.COMMUNICATION
# 1     None                None
# 2     None                None
# 3     None                None
# 4     None                None
# 5     None                None
# 6     None                None
# 7    NOUNS  NOUN.COMMUNICATION
# 8     None                None
# 9     None                None

# %%
result_df.to_csv('filtered_keywords_cleaned.csv', index=False)
