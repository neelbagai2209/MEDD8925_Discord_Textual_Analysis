# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import emoji  # Install with `!pip install emoji`

# Download necessary NLTK resources (run this once)
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

# Initialize tools
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words("english"))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\neelb\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\neelb\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\neelb\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def remove_usernames(text):
    """
    Removes usernames that appear at the start of the line or are followed by a colon.
    Replaces the username with a space to avoid concatenation issues.
    """
    # Replace username pattern with a space
    text = re.sub(r"\b[\w.\s]+(?=\s*:)", " ", text)
    return text

# %%
def remove_bot_commands(text):
    """
    Removes bot commands like '!command' or '?command' and @mentions.
    """
    text = re.sub(r'\?\w+\s?@\w+', '', text)  # Remove bot commands like "?warn @user"
    text = re.sub(r'!\w+\s?@\w+', '', text)  # Remove bot commands like "!rank @user"
    text = re.sub(r'@\w+', '', text)  # Remove @mentions
    return text

# %%
def format_text(text):
    """
    Formats text by:
    - Replacing multiple newlines with single spaces.
    - Ensuring spaces exist around punctuation.
    - Correcting common phrasing issues.
    """
    # Replace multiple newlines or mixed spaces/newlines with a single space
    text = re.sub(r'\s*\n\s*', ' ', text)

    # Add a space after punctuation if it's missing
    text = re.sub(r'(?<=[.,!?])(?=\S)', ' ', text)

    # Correct specific known concatenation patterns
    text = re.sub(r'\bitnthats\b', "it that's", text, flags=re.IGNORECASE)  # Correct "itnthats"
    text = re.sub(r'\btherewego\b', "there we go", text, flags=re.IGNORECASE)  # Correct "therewego"
    text = re.sub(r'\bgonlmao\b', "gon lmao", text, flags=re.IGNORECASE)  # Correct "gonlmao"

    # Ensure proper spacing between words
    text = re.sub(r'(?<=[a-zA-Z])(?=[A-Z])', ' ', text)  # Split camel case, if any
    text = re.sub(r'(?<=[a-zA-Z])(?=\d)', ' ', text)  # Split words from numbers, if concatenated

    # Strip extra spaces
    text = " ".join(text.split())

    return text

# %%
def clean_text(text):
    """
    Cleans and preprocesses text:
    - Removes usernames, bot commands, and emojis.
    - Retains meaningful structure without removing critical stopwords or context.
    """
    text = remove_usernames(text)  # Remove usernames
    text = remove_bot_commands(text)  # Remove bot commands
    text = format_text(text)  # Properly handle newlines and spacing
    text = emoji.replace_emoji(text, replace="")  # Remove emojis
    text = re.sub(r"http\S+|www\S+", "", text)  # Remove URLs
    text = re.sub(r"[^a-zA-Z0-9\s.,!?']", "", text)  # Retain alphanumeric characters and basic punctuation
    text = text.lower().strip()  # Convert to lowercase

    return text

# %%
def clean_text_file(input_file, output_file):
    """
    Reads a text file, cleans its contents, and writes the cleaned data to a new file.
    """
    cleaned_lines = []

    with open(input_file, 'r', encoding='utf-8') as file:
        for line in file:
            cleaned_line = clean_text(line)  # Apply the cleaning pipeline
            cleaned_lines.append(cleaned_line.strip())

    # Write the cleaned data to the output file
    with open(output_file, 'w', encoding='utf-8') as file:
        file.write("\n".join(cleaned_lines))

# %%
import os

def process_all_files(input_folder, output_folder):
    """
    Processes all text files in the input folder, cleans them, and saves the results in the output folder.
    """
    # Create the output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    # Process each text file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(".txt"):
            input_file_path = os.path.join(input_folder, filename)
            output_file_name = os.path.splitext(filename)[0] + "_Cleaned.txt"
            output_file_path = os.path.join(output_folder, output_file_name)

            clean_text_file(input_file_path, output_file_path)
            print(f"✅ Processed and cleaned: {filename}")

    print(f"✅ All files cleaned and saved in {output_folder}")

# %%
# Example problematic text
example_text = "middle eastern: not, itnthats how it is therewego lmao gonlmao i can almost guarantee itnthats true"

# Clean the text
cleaned_text = clean_text(example_text)
print("Original Text:", example_text)
print("Cleaned Text:", cleaned_text)
# Out:
# Original Text: middle eastern: not, itnthats how it is therewego lmao gonlmao i can almost guarantee itnthats true
# Cleaned Text: not, it that's how it is there we go lmao gon lmao i can almost guarantee it that's true

# %%
# Define input and output folders
input_folder = r"C:\Users\neelb\Desktop\MEDD8925 - Analyzing Data Quantitatively\MEDD8925 Discord Project\Discord Data v3 Antispam"
output_folder = r"C:\Users\neelb\Desktop\MEDD8925 - Analyzing Data Quantitatively\MEDD8925 Discord Project\Cleaned Discord Data"

# Process all files in the folder
process_all_files(input_folder, output_folder)
# Out:
# ✅ Processed and cleaned: [298954459172700181] [part 10].txt
# ✅ Processed and cleaned: [298954459172700181] [part 11].txt
# ✅ Processed and cleaned: [298954459172700181] [part 12].txt
# ✅ Processed and cleaned: [298954459172700181] [part 13].txt
# ✅ Processed and cleaned: [298954459172700181] [part 2].txt
# ✅ Processed and cleaned: [298954459172700181] [part 3].txt
# ✅ Processed and cleaned: [298954459172700181] [part 4].txt
# ✅ Processed and cleaned: [298954459172700181] [part 5].txt
# ✅ Processed and cleaned: [298954459172700181] [part 6].txt
# ✅ Processed and cleaned: [298954459172700181] [part 7].txt
# ✅ Processed and cleaned: [298954459172700181] [part 8].txt
# ✅ Processed and cleaned: [298954459172700181] [part 9].txt
# ✅ Processed and cleaned: [298954459172700181].txt
# ✅ Processed and cleaned: [360462032811851778] [part 10].txt
# ✅ Processed and cleaned: [360462032811851778] [part 11].txt
# ✅ Processed and cleaned: [360462032811851778] [part 12].txt
# ✅ Processed and cleaned: [360462032811851778] [part 13].txt
# ✅ Processed and cleaned: [360462032811851778] [part 14].txt
# ✅ Processed and cleaned: [360462032811851778] [part 15].txt
# ✅ Processed and cleaned: [360462032811851778] [part 16].txt
# ✅ Processed and cleaned: [360462032811851778] [part 17].txt
# ✅ Processed and cleaned: [360462032811851778] [part 18].txt
# ✅ Processed and cleaned: [360462032811851778] [part 19].txt
# ✅ Processed and cleaned: [360462032811851778] [part 20].txt
# ✅ Processed and cleaned: [360462032811851778] [part 21].txt
# ✅ Processed and cleaned: [360462032811851778] [part 22].txt
# ✅ Processed and cleaned: [360462032811851778] [part 23].txt
# ✅ Processed and cleaned: [360462032811851778] [part 24].txt
# ✅ Processed and cleaned: [360462032811851778] [part 25].txt
# ✅ Processed and cleaned: [360462032811851778] [part 26].txt
# ✅ Processed and cleaned: [360462032811851778] [part 27].txt
# ✅ Processed and cleaned: [360462032811851778] [part 28].txt
# ✅ Processed and cleaned: [360462032811851778] [part 29].txt
# ✅ Processed and cleaned: [360462032811851778] [part 2].txt
# ✅ Processed and cleaned: [360462032811851778] [part 30].txt
# ✅ Processed and cleaned: [360462032811851778] [part 31].txt
# ✅ Processed and cleaned: [360462032811851778] [part 32].txt
# ✅ Processed and cleaned: [360462032811851778] [part 33].txt
# ✅ Processed and cleaned: [360462032811851778] [part 34].txt
# ✅ Processed and cleaned: [360462032811851778] [part 35].txt
# ✅ Processed and cleaned: [360462032811851778] [part 36].txt
# ✅ Processed and cleaned: [360462032811851778] [part 37].txt
# ✅ Processed and cleaned: [360462032811851778] [part 38].txt
# ✅ Processed and cleaned: [360462032811851778] [part 39].txt
# ✅ Processed and cleaned: [360462032811851778] [part 3].txt
# ✅ Processed and cleaned: [360462032811851778] [part 40].txt
# ✅ Processed and cleaned: [360462032811851778] [part 41].txt
# ✅ Processed and cleaned: [360462032811851778] [part 42].txt
# ✅ Processed and cleaned: [360462032811851778] [part 43].txt
# ✅ Processed and cleaned: [360462032811851778] [part 44].txt
# ✅ Processed and cleaned: [360462032811851778] [part 45].txt
# ✅ Processed and cleaned: [360462032811851778] [part 46].txt
# ✅ Processed and cleaned: [360462032811851778] [part 4].txt
# ✅ Processed and cleaned: [360462032811851778] [part 5].txt
# ✅ Processed and cleaned: [360462032811851778] [part 6].txt
# ✅ Processed and cleaned: [360462032811851778] [part 7].txt
# ✅ Processed and cleaned: [360462032811851778] [part 8].txt
# ✅ Processed and cleaned: [360462032811851778] [part 9].txt
# ✅ Processed and cleaned: [360462032811851778].txt
# ✅ Processed and cleaned: [390037306230177803] [part 10].txt
# ✅ Processed and cleaned: [390037306230177803] [part 2].txt
# ✅ Processed and cleaned: [390037306230177803] [part 3].txt
# ✅ Processed and cleaned: [390037306230177803] [part 4].txt
# ✅ Processed and cleaned: [390037306230177803] [part 5].txt
# ✅ Processed and cleaned: [390037306230177803] [part 6].txt
# ✅ Processed and cleaned: [390037306230177803] [part 7].txt
# ✅ Processed and cleaned: [390037306230177803] [part 8].txt
# ✅ Processed and cleaned: [390037306230177803] [part 9].txt
# ✅ Processed and cleaned: [390037306230177803].txt
# ✅ Processed and cleaned: [413225913254412288] [part 10].txt
# ✅ Processed and cleaned: [413225913254412288] [part 11].txt
# ✅ Processed and cleaned: [413225913254412288] [part 12].txt
# ✅ Processed and cleaned: [413225913254412288] [part 13].txt
# ✅ Processed and cleaned: [413225913254412288] [part 14].txt
# ✅ Processed and cleaned: [413225913254412288] [part 15].txt
# ✅ Processed and cleaned: [413225913254412288] [part 16].txt
# ✅ Processed and cleaned: [413225913254412288] [part 17].txt
# ✅ Processed and cleaned: [413225913254412288] [part 18].txt
# ✅ Processed and cleaned: [413225913254412288] [part 19].txt
# ✅ Processed and cleaned: [413225913254412288] [part 20].txt
# ✅ Processed and cleaned: [413225913254412288] [part 21].txt
# ✅ Processed and cleaned: [413225913254412288] [part 22].txt
# ✅ Processed and cleaned: [413225913254412288] [part 23].txt
# ✅ Processed and cleaned: [413225913254412288] [part 24].txt
# ✅ Processed and cleaned: [413225913254412288] [part 25].txt
# ✅ Processed and cleaned: [413225913254412288] [part 26].txt
# ✅ Processed and cleaned: [413225913254412288] [part 27].txt
# ✅ Processed and cleaned: [413225913254412288] [part 28].txt
# ✅ Processed and cleaned: [413225913254412288] [part 29].txt
# ✅ Processed and cleaned: [413225913254412288] [part 2].txt
# ✅ Processed and cleaned: [413225913254412288] [part 30].txt
# ✅ Processed and cleaned: [413225913254412288] [part 31].txt
# ✅ Processed and cleaned: [413225913254412288] [part 32].txt
# ✅ Processed and cleaned: [413225913254412288] [part 33].txt
# ✅ Processed and cleaned: [413225913254412288] [part 34].txt
# ✅ Processed and cleaned: [413225913254412288] [part 35].txt
# ✅ Processed and cleaned: [413225913254412288] [part 36].txt
# ✅ Processed and cleaned: [413225913254412288] [part 37].txt
# ✅ Processed and cleaned: [413225913254412288] [part 38].txt
# ✅ Processed and cleaned: [413225913254412288] [part 39].txt
# ✅ Processed and cleaned: [413225913254412288] [part 3].txt
# ✅ Processed and cleaned: [413225913254412288] [part 40].txt
# ✅ Processed and cleaned: [413225913254412288] [part 41].txt
# ✅ Processed and cleaned: [413225913254412288] [part 42].txt
# ✅ Processed and cleaned: [413225913254412288] [part 43].txt
# ✅ Processed and cleaned: [413225913254412288] [part 44].txt
# ✅ Processed and cleaned: [413225913254412288] [part 45].txt
# ✅ Processed and cleaned: [413225913254412288] [part 46].txt
# ✅ Processed and cleaned: [413225913254412288] [part 47].txt
# ✅ Processed and cleaned: [413225913254412288] [part 4].txt
# ✅ Processed and cleaned: [413225913254412288] [part 5].txt
# ✅ Processed and cleaned: [413225913254412288] [part 6].txt
# ✅ Processed and cleaned: [413225913254412288] [part 7].txt
# ✅ Processed and cleaned: [413225913254412288] [part 8].txt
# ✅ Processed and cleaned: [413225913254412288] [part 9].txt
# ✅ Processed and cleaned: [413225913254412288].txt
# ✅ Processed and cleaned: [451466119338000405] [part 10].txt
# ✅ Processed and cleaned: [451466119338000405] [part 11].txt
# ✅ Processed and cleaned: [451466119338000405] [part 2].txt
# ✅ Processed and cleaned: [451466119338000405] [part 3].txt
# ✅ Processed and cleaned: [451466119338000405] [part 4].txt
# ✅ Processed and cleaned: [451466119338000405] [part 5].txt
# ✅ Processed and cleaned: [451466119338000405] [part 6].txt
# ✅ Processed and cleaned: [451466119338000405] [part 7].txt
# ✅ Processed and cleaned: [451466119338000405] [part 8].txt
# ✅ Processed and cleaned: [451466119338000405] [part 9].txt
# ✅ Processed and cleaned: [451466119338000405].txt
# ✅ Processed and cleaned: [490935325259202560] [part 10].txt
# ✅ Processed and cleaned: [490935325259202560] [part 11].txt
# ✅ Processed and cleaned: [490935325259202560] [part 12].txt
# ✅ Processed and cleaned: [490935325259202560] [part 13].txt
# ✅ Processed and cleaned: [490935325259202560] [part 14].txt
# ✅ Processed and cleaned: [490935325259202560] [part 15].txt
# ✅ Processed and cleaned: [490935325259202560] [part 16].txt
# ✅ Processed and cleaned: [490935325259202560] [part 17].txt
# ✅ Processed and cleaned: [490935325259202560] [part 18].txt
# ✅ Processed and cleaned: [490935325259202560] [part 19].txt
# ✅ Processed and cleaned: [490935325259202560] [part 20].txt
# ✅ Processed and cleaned: [490935325259202560] [part 21].txt
# ✅ Processed and cleaned: [490935325259202560] [part 22].txt
# ✅ Processed and cleaned: [490935325259202560] [part 23].txt
# ✅ Processed and cleaned: [490935325259202560] [part 24].txt
# ✅ Processed and cleaned: [490935325259202560] [part 25].txt
# ✅ Processed and cleaned: [490935325259202560] [part 26].txt
# ✅ Processed and cleaned: [490935325259202560] [part 27].txt
# ✅ Processed and cleaned: [490935325259202560] [part 28].txt
# ✅ Processed and cleaned: [490935325259202560] [part 29].txt
# ✅ Processed and cleaned: [490935325259202560] [part 2].txt
# ✅ Processed and cleaned: [490935325259202560] [part 30].txt
# ✅ Processed and cleaned: [490935325259202560] [part 31].txt
# ✅ Processed and cleaned: [490935325259202560] [part 32].txt
# ✅ Processed and cleaned: [490935325259202560] [part 33].txt
# ✅ Processed and cleaned: [490935325259202560] [part 34].txt
# ✅ Processed and cleaned: [490935325259202560] [part 35].txt
# ✅ Processed and cleaned: [490935325259202560] [part 36].txt
# ✅ Processed and cleaned: [490935325259202560] [part 37].txt
# ✅ Processed and cleaned: [490935325259202560] [part 38].txt
# ✅ Processed and cleaned: [490935325259202560] [part 39].txt
# ✅ Processed and cleaned: [490935325259202560] [part 3].txt
# ✅ Processed and cleaned: [490935325259202560] [part 40].txt
# ✅ Processed and cleaned: [490935325259202560] [part 41].txt
# ✅ Processed and cleaned: [490935325259202560] [part 42].txt
# ✅ Processed and cleaned: [490935325259202560] [part 43].txt
# ✅ Processed and cleaned: [490935325259202560] [part 44].txt
# ✅ Processed and cleaned: [490935325259202560] [part 4].txt
# ✅ Processed and cleaned: [490935325259202560] [part 5].txt
# ✅ Processed and cleaned: [490935325259202560] [part 6].txt
# ✅ Processed and cleaned: [490935325259202560] [part 7].txt
# ✅ Processed and cleaned: [490935325259202560] [part 8].txt
# ✅ Processed and cleaned: [490935325259202560] [part 9].txt
# ✅ Processed and cleaned: [490935325259202560].txt
# ✅ Processed and cleaned: [510987107087679512] [part 10].txt
# ✅ Processed and cleaned: [510987107087679512] [part 11].txt
# ✅ Processed and cleaned: [510987107087679512] [part 12].txt
# ✅ Processed and cleaned: [510987107087679512] [part 13].txt
# ✅ Processed and cleaned: [510987107087679512] [part 14].txt
# ✅ Processed and cleaned: [510987107087679512] [part 15].txt
# ✅ Processed and cleaned: [510987107087679512] [part 16].txt
# ✅ Processed and cleaned: [510987107087679512] [part 17].txt
# ✅ Processed and cleaned: [510987107087679512] [part 18].txt
# ✅ Processed and cleaned: [510987107087679512] [part 19].txt
# ✅ Processed and cleaned: [510987107087679512] [part 20].txt
# ✅ Processed and cleaned: [510987107087679512] [part 21].txt
# ✅ Processed and cleaned: [510987107087679512] [part 22].txt
# ✅ Processed and cleaned: [510987107087679512] [part 23].txt
# ✅ Processed and cleaned: [510987107087679512] [part 24].txt
# ✅ Processed and cleaned: [510987107087679512] [part 25].txt
# ✅ Processed and cleaned: [510987107087679512] [part 26].txt
# ✅ Processed and cleaned: [510987107087679512] [part 27].txt
# ✅ Processed and cleaned: [510987107087679512] [part 28].txt
# ✅ Processed and cleaned: [510987107087679512] [part 29].txt
# ✅ Processed and cleaned: [510987107087679512] [part 2].txt
# ✅ Processed and cleaned: [510987107087679512] [part 30].txt
# ✅ Processed and cleaned: [510987107087679512] [part 31].txt
# ✅ Processed and cleaned: [510987107087679512] [part 32].txt
# ✅ Processed and cleaned: [510987107087679512] [part 33].txt
# ✅ Processed and cleaned: [510987107087679512] [part 34].txt
# ✅ Processed and cleaned: [510987107087679512] [part 35].txt
# ✅ Processed and cleaned: [510987107087679512] [part 36].txt
# ✅ Processed and cleaned: [510987107087679512] [part 37].txt
# ✅ Processed and cleaned: [510987107087679512] [part 38].txt
# ✅ Processed and cleaned: [510987107087679512] [part 39].txt
# ✅ Processed and cleaned: [510987107087679512] [part 3].txt
# ✅ Processed and cleaned: [510987107087679512] [part 40].txt
# ✅ Processed and cleaned: [510987107087679512] [part 41].txt
# ✅ Processed and cleaned: [510987107087679512] [part 42].txt
# ✅ Processed and cleaned: [510987107087679512] [part 43].txt
# ✅ Processed and cleaned: [510987107087679512] [part 44].txt
# ✅ Processed and cleaned: [510987107087679512] [part 45].txt
# ✅ Processed and cleaned: [510987107087679512] [part 46].txt
# ✅ Processed and cleaned: [510987107087679512] [part 47].txt
# ✅ Processed and cleaned: [510987107087679512] [part 4].txt
# ✅ Processed and cleaned: [510987107087679512] [part 5].txt
# ✅ Processed and cleaned: [510987107087679512] [part 6].txt
# ✅ Processed and cleaned: [510987107087679512] [part 7].txt
# ✅ Processed and cleaned: [510987107087679512] [part 8].txt
# ✅ Processed and cleaned: [510987107087679512] [part 9].txt
# ✅ Processed and cleaned: [510987107087679512].txt
# ✅ Processed and cleaned: [540926126285914112] [part 10].txt
# ✅ Processed and cleaned: [540926126285914112] [part 11].txt
# ✅ Processed and cleaned: [540926126285914112] [part 12].txt
# ✅ Processed and cleaned: [540926126285914112] [part 13].txt
# ✅ Processed and cleaned: [540926126285914112] [part 14].txt
# ✅ Processed and cleaned: [540926126285914112] [part 15].txt
# ✅ Processed and cleaned: [540926126285914112] [part 16].txt
# ✅ Processed and cleaned: [540926126285914112] [part 17].txt
# ✅ Processed and cleaned: [540926126285914112] [part 18].txt
# ✅ Processed and cleaned: [540926126285914112] [part 19].txt
# ✅ Processed and cleaned: [540926126285914112] [part 20].txt
# ✅ Processed and cleaned: [540926126285914112] [part 21].txt
# ✅ Processed and cleaned: [540926126285914112] [part 22].txt
# ✅ Processed and cleaned: [540926126285914112] [part 23].txt
# ✅ Processed and cleaned: [540926126285914112] [part 24].txt
# ✅ Processed and cleaned: [540926126285914112] [part 25].txt
# ✅ Processed and cleaned: [540926126285914112] [part 26].txt
# ✅ Processed and cleaned: [540926126285914112] [part 27].txt
# ✅ Processed and cleaned: [540926126285914112] [part 2].txt
# ✅ Processed and cleaned: [540926126285914112] [part 3].txt
# ✅ Processed and cleaned: [540926126285914112] [part 4].txt
# ✅ Processed and cleaned: [540926126285914112] [part 5].txt
# ✅ Processed and cleaned: [540926126285914112] [part 6].txt
# ✅ Processed and cleaned: [540926126285914112] [part 7].txt
# ✅ Processed and cleaned: [540926126285914112] [part 8].txt
# ✅ Processed and cleaned: [540926126285914112] [part 9].txt
# ✅ Processed and cleaned: [540926126285914112].txt
# ✅ Processed and cleaned: [542291426051096606] [part 10].txt
# ✅ Processed and cleaned: [542291426051096606] [part 11].txt
# ✅ Processed and cleaned: [542291426051096606] [part 12].txt
# ✅ Processed and cleaned: [542291426051096606] [part 13].txt
# ✅ Processed and cleaned: [542291426051096606] [part 14].txt
# ✅ Processed and cleaned: [542291426051096606] [part 15].txt
# ✅ Processed and cleaned: [542291426051096606] [part 16].txt
# ✅ Processed and cleaned: [542291426051096606] [part 17].txt
# ✅ Processed and cleaned: [542291426051096606] [part 18].txt
# ✅ Processed and cleaned: [542291426051096606] [part 19].txt
# ✅ Processed and cleaned: [542291426051096606] [part 20].txt
# ✅ Processed and cleaned: [542291426051096606] [part 21].txt
# ✅ Processed and cleaned: [542291426051096606] [part 22].txt
# ✅ Processed and cleaned: [542291426051096606] [part 23].txt
# ✅ Processed and cleaned: [542291426051096606] [part 24].txt
# ✅ Processed and cleaned: [542291426051096606] [part 25].txt
# ✅ Processed and cleaned: [542291426051096606] [part 26].txt
# ✅ Processed and cleaned: [542291426051096606] [part 27].txt
# ✅ Processed and cleaned: [542291426051096606] [part 28].txt
# ✅ Processed and cleaned: [542291426051096606] [part 2].txt
# ✅ Processed and cleaned: [542291426051096606] [part 3].txt
# ✅ Processed and cleaned: [542291426051096606] [part 4].txt
# ✅ Processed and cleaned: [542291426051096606] [part 5].txt
# ✅ Processed and cleaned: [542291426051096606] [part 6].txt
# ✅ Processed and cleaned: [542291426051096606] [part 7].txt
# ✅ Processed and cleaned: [542291426051096606] [part 8].txt
# ✅ Processed and cleaned: [542291426051096606] [part 9].txt
# ✅ Processed and cleaned: [542291426051096606].txt
# ✅ Processed and cleaned: [568279918111227924] [part 10].txt
# ✅ Processed and cleaned: [568279918111227924] [part 11].txt
# ✅ Processed and cleaned: [568279918111227924] [part 12].txt
# ✅ Processed and cleaned: [568279918111227924] [part 13].txt
# ✅ Processed and cleaned: [568279918111227924] [part 14].txt
# ✅ Processed and cleaned: [568279918111227924] [part 15].txt
# ✅ Processed and cleaned: [568279918111227924] [part 16].txt
# ✅ Processed and cleaned: [568279918111227924] [part 17].txt
# ✅ Processed and cleaned: [568279918111227924] [part 18].txt
# ✅ Processed and cleaned: [568279918111227924] [part 19].txt
# ✅ Processed and cleaned: [568279918111227924] [part 20].txt
# ✅ Processed and cleaned: [568279918111227924] [part 21].txt
# ✅ Processed and cleaned: [568279918111227924] [part 22].txt
# ✅ Processed and cleaned: [568279918111227924] [part 23].txt
# ✅ Processed and cleaned: [568279918111227924] [part 24].txt
# ✅ Processed and cleaned: [568279918111227924] [part 25].txt
# ✅ Processed and cleaned: [568279918111227924] [part 26].txt
# ✅ Processed and cleaned: [568279918111227924] [part 27].txt
# ✅ Processed and cleaned: [568279918111227924] [part 28].txt
# ✅ Processed and cleaned: [568279918111227924] [part 29].txt
# ✅ Processed and cleaned: [568279918111227924] [part 2].txt
# ✅ Processed and cleaned: [568279918111227924] [part 30].txt
# ✅ Processed and cleaned: [568279918111227924] [part 31].txt
# ✅ Processed and cleaned: [568279918111227924] [part 32].txt
# ✅ Processed and cleaned: [568279918111227924] [part 33].txt
# ✅ Processed and cleaned: [568279918111227924] [part 3].txt
# ✅ Processed and cleaned: [568279918111227924] [part 4].txt
# ✅ Processed and cleaned: [568279918111227924] [part 5].txt
# ✅ Processed and cleaned: [568279918111227924] [part 6].txt
# ✅ Processed and cleaned: [568279918111227924] [part 7].txt
# ✅ Processed and cleaned: [568279918111227924] [part 8].txt
# ✅ Processed and cleaned: [568279918111227924] [part 9].txt
# ✅ Processed and cleaned: [568279918111227924].txt
# ✅ Processed and cleaned: [575824180126416901] [part 10].txt
# ✅ Processed and cleaned: [575824180126416901] [part 11].txt
# ✅ Processed and cleaned: [575824180126416901] [part 12].txt
# ✅ Processed and cleaned: [575824180126416901] [part 13].txt
# ✅ Processed and cleaned: [575824180126416901] [part 14].txt
# ✅ Processed and cleaned: [575824180126416901] [part 15].txt
# ✅ Processed and cleaned: [575824180126416901] [part 16].txt
# ✅ Processed and cleaned: [575824180126416901] [part 17].txt
# ✅ Processed and cleaned: [575824180126416901] [part 18].txt
# ✅ Processed and cleaned: [575824180126416901] [part 19].txt
# ✅ Processed and cleaned: [575824180126416901] [part 20].txt
# ✅ Processed and cleaned: [575824180126416901] [part 21].txt
# ✅ Processed and cleaned: [575824180126416901] [part 22].txt
# ✅ Processed and cleaned: [575824180126416901] [part 23].txt
# ✅ Processed and cleaned: [575824180126416901] [part 24].txt
# ✅ Processed and cleaned: [575824180126416901] [part 25].txt
# ✅ Processed and cleaned: [575824180126416901] [part 26].txt
# ✅ Processed and cleaned: [575824180126416901] [part 27].txt
# ✅ Processed and cleaned: [575824180126416901] [part 28].txt
# ✅ Processed and cleaned: [575824180126416901] [part 29].txt
# ✅ Processed and cleaned: [575824180126416901] [part 2].txt
# ✅ Processed and cleaned: [575824180126416901] [part 30].txt
# ✅ Processed and cleaned: [575824180126416901] [part 31].txt
# ✅ Processed and cleaned: [575824180126416901] [part 3].txt
# ✅ Processed and cleaned: [575824180126416901] [part 4].txt
# ✅ Processed and cleaned: [575824180126416901] [part 5].txt
# ✅ Processed and cleaned: [575824180126416901] [part 6].txt
# ✅ Processed and cleaned: [575824180126416901] [part 7].txt
# ✅ Processed and cleaned: [575824180126416901] [part 8].txt
# ✅ Processed and cleaned: [575824180126416901] [part 9].txt
# ✅ Processed and cleaned: [575824180126416901].txt
# ✅ Processed and cleaned: [585773879512006656] [part 10].txt
# ✅ Processed and cleaned: [585773879512006656] [part 2].txt
# ✅ Processed and cleaned: [585773879512006656] [part 3].txt
# ✅ Processed and cleaned: [585773879512006656] [part 4].txt
# ✅ Processed and cleaned: [585773879512006656] [part 5].txt
# ✅ Processed and cleaned: [585773879512006656] [part 6].txt
# ✅ Processed and cleaned: [585773879512006656] [part 7].txt
# ✅ Processed and cleaned: [585773879512006656] [part 8].txt
# ✅ Processed and cleaned: [585773879512006656] [part 9].txt
# ✅ Processed and cleaned: [585773879512006656].txt
# ✅ Processed and cleaned: [616923932477620249] [part 10].txt
# ✅ Processed and cleaned: [616923932477620249] [part 11].txt
# ✅ Processed and cleaned: [616923932477620249] [part 12].txt
# ✅ Processed and cleaned: [616923932477620249] [part 13].txt
# ✅ Processed and cleaned: [616923932477620249] [part 14].txt
# ✅ Processed and cleaned: [616923932477620249] [part 15].txt
# ✅ Processed and cleaned: [616923932477620249] [part 16].txt
# ✅ Processed and cleaned: [616923932477620249] [part 17].txt
# ✅ Processed and cleaned: [616923932477620249] [part 18].txt
# ✅ Processed and cleaned: [616923932477620249] [part 19].txt
# ✅ Processed and cleaned: [616923932477620249] [part 20].txt
# ✅ Processed and cleaned: [616923932477620249] [part 21].txt
# ✅ Processed and cleaned: [616923932477620249] [part 22].txt
# ✅ Processed and cleaned: [616923932477620249] [part 23].txt
# ✅ Processed and cleaned: [616923932477620249] [part 24].txt
# ✅ Processed and cleaned: [616923932477620249] [part 25].txt
# ✅ Processed and cleaned: [616923932477620249] [part 26].txt
# ✅ Processed and cleaned: [616923932477620249] [part 27].txt
# ✅ Processed and cleaned: [616923932477620249] [part 28].txt
# ✅ Processed and cleaned: [616923932477620249] [part 29].txt
# ✅ Processed and cleaned: [616923932477620249] [part 2].txt
# ✅ Processed and cleaned: [616923932477620249] [part 30].txt
# ✅ Processed and cleaned: [616923932477620249] [part 3].txt
# ✅ Processed and cleaned: [616923932477620249] [part 4].txt
# ✅ Processed and cleaned: [616923932477620249] [part 5].txt
# ✅ Processed and cleaned: [616923932477620249] [part 6].txt
# ✅ Processed and cleaned: [616923932477620249] [part 7].txt
# ✅ Processed and cleaned: [616923932477620249] [part 8].txt
# ✅ Processed and cleaned: [616923932477620249] [part 9].txt
# ✅ Processed and cleaned: [616923932477620249].txt
# ✅ Processed and cleaned: [646531991663280140] [part 10].txt
# ✅ Processed and cleaned: [646531991663280140] [part 11].txt
# ✅ Processed and cleaned: [646531991663280140] [part 12].txt
# ✅ Processed and cleaned: [646531991663280140] [part 13].txt
# ✅ Processed and cleaned: [646531991663280140] [part 2].txt
# ✅ Processed and cleaned: [646531991663280140] [part 3].txt
# ✅ Processed and cleaned: [646531991663280140] [part 4].txt
# ✅ Processed and cleaned: [646531991663280140] [part 5].txt
# ✅ Processed and cleaned: [646531991663280140] [part 6].txt
# ✅ Processed and cleaned: [646531991663280140] [part 7].txt
# ✅ Processed and cleaned: [646531991663280140] [part 8].txt
# ✅ Processed and cleaned: [646531991663280140] [part 9].txt
# ✅ Processed and cleaned: [646531991663280140].txt
# ✅ Processed and cleaned: [655749612384288816] [part 2].txt
# ✅ Processed and cleaned: [655749612384288816] [part 3].txt
# ✅ Processed and cleaned: [655749612384288816] [part 4].txt
# ✅ Processed and cleaned: [655749612384288816] [part 5].txt
# ✅ Processed and cleaned: [655749612384288816] [part 6].txt
# ✅ Processed and cleaned: [655749612384288816] [part 7].txt
# ✅ Processed and cleaned: [655749612384288816].txt
# ✅ Processed and cleaned: [661670915439984692] [part 2].txt
# ✅ Processed and cleaned: [661670915439984692] [part 3].txt
# ✅ Processed and cleaned: [661670915439984692] [part 4].txt
# ✅ Processed and cleaned: [661670915439984692] [part 5].txt
# ✅ Processed and cleaned: [661670915439984692].txt
# ✅ Processed and cleaned: [665562266837450755] [part 2].txt
# ✅ Processed and cleaned: [665562266837450755] [part 3].txt
# ✅ Processed and cleaned: [665562266837450755] [part 4].txt
# ✅ Processed and cleaned: [665562266837450755] [part 5].txt
# ✅ Processed and cleaned: [665562266837450755].txt
# ✅ Processed and cleaned: [681363568293183489] [part 10].txt
# ✅ Processed and cleaned: [681363568293183489] [part 11].txt
# ✅ Processed and cleaned: [681363568293183489] [part 12].txt
# ✅ Processed and cleaned: [681363568293183489] [part 13].txt
# ✅ Processed and cleaned: [681363568293183489] [part 14].txt
# ✅ Processed and cleaned: [681363568293183489] [part 15].txt
# ✅ Processed and cleaned: [681363568293183489] [part 16].txt
# ✅ Processed and cleaned: [681363568293183489] [part 2].txt
# ✅ Processed and cleaned: [681363568293183489] [part 3].txt
# ✅ Processed and cleaned: [681363568293183489] [part 4].txt
# ✅ Processed and cleaned: [681363568293183489] [part 5].txt
# ✅ Processed and cleaned: [681363568293183489] [part 6].txt
# ✅ Processed and cleaned: [681363568293183489] [part 7].txt
# ✅ Processed and cleaned: [681363568293183489] [part 8].txt
# ✅ Processed and cleaned: [681363568293183489] [part 9].txt
# ✅ Processed and cleaned: [681363568293183489].txt
# ✅ Processed and cleaned: [689963458967765003] [part 10].txt
# ✅ Processed and cleaned: [689963458967765003] [part 11].txt
# ✅ Processed and cleaned: [689963458967765003] [part 12].txt
# ✅ Processed and cleaned: [689963458967765003] [part 2].txt
# ✅ Processed and cleaned: [689963458967765003] [part 3].txt
# ✅ Processed and cleaned: [689963458967765003] [part 4].txt
# ✅ Processed and cleaned: [689963458967765003] [part 5].txt
# ✅ Processed and cleaned: [689963458967765003] [part 6].txt
# ✅ Processed and cleaned: [689963458967765003] [part 7].txt
# ✅ Processed and cleaned: [689963458967765003] [part 8].txt
# ✅ Processed and cleaned: [689963458967765003] [part 9].txt
# ✅ Processed and cleaned: [689963458967765003].txt
# ✅ Processed and cleaned: [690385418591666196] [part 2].txt
# ✅ Processed and cleaned: [690385418591666196] [part 3].txt
# ✅ Processed and cleaned: [690385418591666196] [part 4].txt
# ✅ Processed and cleaned: [690385418591666196] [part 5].txt
# ✅ Processed and cleaned: [690385418591666196] [part 6].txt
# ✅ Processed and cleaned: [690385418591666196].txt
# ✅ Processed and cleaned: [690981388299665478] [part 10].txt
# ✅ Processed and cleaned: [690981388299665478] [part 11].txt
# ✅ Processed and cleaned: [690981388299665478] [part 12].txt
# ✅ Processed and cleaned: [690981388299665478] [part 13].txt
# ✅ Processed and cleaned: [690981388299665478] [part 2].txt
# ✅ Processed and cleaned: [690981388299665478] [part 3].txt
# ✅ Processed and cleaned: [690981388299665478] [part 4].txt
# ✅ Processed and cleaned: [690981388299665478] [part 5].txt
# ✅ Processed and cleaned: [690981388299665478] [part 6].txt
# ✅ Processed and cleaned: [690981388299665478] [part 7].txt
# ✅ Processed and cleaned: [690981388299665478] [part 8].txt
# ✅ Processed and cleaned: [690981388299665478] [part 9].txt
# ✅ Processed and cleaned: [690981388299665478].txt
# ✅ Processed and cleaned: [691530076344287252].txt
# ✅ Processed and cleaned: [691534378190241862].txt
# ✅ Processed and cleaned: [691541833561407498] [part 2].txt
# ✅ Processed and cleaned: [691541833561407498] [part 3].txt
# ✅ Processed and cleaned: [691541833561407498].txt
# ✅ Processed and cleaned: [691542050578890802] [part 10].txt
# ✅ Processed and cleaned: [691542050578890802] [part 11].txt
# ✅ Processed and cleaned: [691542050578890802] [part 12].txt
# ✅ Processed and cleaned: [691542050578890802] [part 13].txt
# ✅ Processed and cleaned: [691542050578890802] [part 14].txt
# ✅ Processed and cleaned: [691542050578890802] [part 15].txt
# ✅ Processed and cleaned: [691542050578890802] [part 16].txt
# ✅ Processed and cleaned: [691542050578890802] [part 17].txt
# ✅ Processed and cleaned: [691542050578890802] [part 18].txt
# ✅ Processed and cleaned: [691542050578890802] [part 19].txt
# ✅ Processed and cleaned: [691542050578890802] [part 2].txt
# ✅ Processed and cleaned: [691542050578890802] [part 3].txt
# ✅ Processed and cleaned: [691542050578890802] [part 4].txt
# ✅ Processed and cleaned: [691542050578890802] [part 5].txt
# ✅ Processed and cleaned: [691542050578890802] [part 6].txt
# ✅ Processed and cleaned: [691542050578890802] [part 7].txt
# ✅ Processed and cleaned: [691542050578890802] [part 8].txt
# ✅ Processed and cleaned: [691542050578890802] [part 9].txt
# ✅ Processed and cleaned: [691542050578890802].txt
# ✅ Processed and cleaned: [692369647659384872].txt
# ✅ Processed and cleaned: [701906138563870840] [part 2].txt
# ✅ Processed and cleaned: [701906138563870840] [part 3].txt
# ✅ Processed and cleaned: [701906138563870840] [part 4].txt
# ✅ Processed and cleaned: [701906138563870840] [part 5].txt
# ✅ Processed and cleaned: [701906138563870840] [part 6].txt
# ✅ Processed and cleaned: [701906138563870840].txt
# ✅ Processed and cleaned: [703541751100473414] [part 10].txt
# ✅ Processed and cleaned: [703541751100473414] [part 2].txt
# ✅ Processed and cleaned: [703541751100473414] [part 3].txt
# ✅ Processed and cleaned: [703541751100473414] [part 4].txt
# ✅ Processed and cleaned: [703541751100473414] [part 5].txt
# ✅ Processed and cleaned: [703541751100473414] [part 6].txt
# ✅ Processed and cleaned: [703541751100473414] [part 7].txt
# ✅ Processed and cleaned: [703541751100473414] [part 8].txt
# ✅ Processed and cleaned: [703541751100473414] [part 9].txt
# ✅ Processed and cleaned: [703541751100473414].txt
# ✅ Processed and cleaned: [704420858902609951] [part 2].txt
# ✅ Processed and cleaned: [704420858902609951] [part 3].txt
# ✅ Processed and cleaned: [704420858902609951] [part 4].txt
# ✅ Processed and cleaned: [704420858902609951] [part 5].txt
# ✅ Processed and cleaned: [704420858902609951] [part 6].txt
# ✅ Processed and cleaned: [704420858902609951] [part 7].txt
# ✅ Processed and cleaned: [704420858902609951] [part 8].txt
# ✅ Processed and cleaned: [704420858902609951] [part 9].txt
# ✅ Processed and cleaned: [704420858902609951].txt
# ✅ Processed and cleaned: [704421902101381150].txt
# ✅ Processed and cleaned: [705362659721084978].txt
# ✅ Processed and cleaned: [705406749460398090] [part 10].txt
# ✅ Processed and cleaned: [705406749460398090] [part 11].txt
# ✅ Processed and cleaned: [705406749460398090] [part 12].txt
# ✅ Processed and cleaned: [705406749460398090] [part 13].txt
# ✅ Processed and cleaned: [705406749460398090] [part 14].txt
# ✅ Processed and cleaned: [705406749460398090] [part 2].txt
# ✅ Processed and cleaned: [705406749460398090] [part 3].txt
# ✅ Processed and cleaned: [705406749460398090] [part 4].txt
# ✅ Processed and cleaned: [705406749460398090] [part 5].txt
# ✅ Processed and cleaned: [705406749460398090] [part 6].txt
# ✅ Processed and cleaned: [705406749460398090] [part 7].txt
# ✅ Processed and cleaned: [705406749460398090] [part 8].txt
# ✅ Processed and cleaned: [705406749460398090] [part 9].txt
# ✅ Processed and cleaned: [705406749460398090].txt
# ✅ Processed and cleaned: [708357723292565516] [part 10].txt
# ✅ Processed and cleaned: [708357723292565516] [part 11].txt
# ✅ Processed and cleaned: [708357723292565516] [part 12].txt
# ✅ Processed and cleaned: [708357723292565516] [part 13].txt
# ✅ Processed and cleaned: [708357723292565516] [part 14].txt
# ✅ Processed and cleaned: [708357723292565516] [part 15].txt
# ✅ Processed and cleaned: [708357723292565516] [part 16].txt
# ✅ Processed and cleaned: [708357723292565516] [part 17].txt
# ✅ Processed and cleaned: [708357723292565516] [part 18].txt
# ✅ Processed and cleaned: [708357723292565516] [part 19].txt
# ✅ Processed and cleaned: [708357723292565516] [part 20].txt
# ✅ Processed and cleaned: [708357723292565516] [part 21].txt
# ✅ Processed and cleaned: [708357723292565516] [part 22].txt
# ✅ Processed and cleaned: [708357723292565516] [part 23].txt
# ✅ Processed and cleaned: [708357723292565516] [part 2].txt
# ✅ Processed and cleaned: [708357723292565516] [part 3].txt
# ✅ Processed and cleaned: [708357723292565516] [part 4].txt
# ✅ Processed and cleaned: [708357723292565516] [part 5].txt
# ✅ Processed and cleaned: [708357723292565516] [part 6].txt
# ✅ Processed and cleaned: [708357723292565516] [part 7].txt
# ✅ Processed and cleaned: [708357723292565516] [part 8].txt
# ✅ Processed and cleaned: [708357723292565516] [part 9].txt
# ✅ Processed and cleaned: [708357723292565516].txt
# ✅ Processed and cleaned: [708810628940431460].txt
# ✅ Processed and cleaned: [713928323805347955] [part 10].txt
# ✅ Processed and cleaned: [713928323805347955] [part 11].txt
# ✅ Processed and cleaned: [713928323805347955] [part 12].txt
# ✅ Processed and cleaned: [713928323805347955] [part 13].txt
# ✅ Processed and cleaned: [713928323805347955] [part 14].txt
# ✅ Processed and cleaned: [713928323805347955] [part 2].txt
# ✅ Processed and cleaned: [713928323805347955] [part 3].txt
# ✅ Processed and cleaned: [713928323805347955] [part 4].txt
# ✅ Processed and cleaned: [713928323805347955] [part 5].txt
# ✅ Processed and cleaned: [713928323805347955] [part 6].txt
# ✅ Processed and cleaned: [713928323805347955] [part 7].txt
# ✅ Processed and cleaned: [713928323805347955] [part 8].txt
# ✅ Processed and cleaned: [713928323805347955] [part 9].txt
# ✅ Processed and cleaned: [713928323805347955].txt
# ✅ Processed and cleaned: [721215902091182170] [part 2].txt
# ✅ Processed and cleaned: [721215902091182170] [part 3].txt
# ✅ Processed and cleaned: [721215902091182170] [part 4].txt
# ✅ Processed and cleaned: [721215902091182170] [part 5].txt
# ✅ Processed and cleaned: [721215902091182170] [part 6].txt
# ✅ Processed and cleaned: [721215902091182170] [part 7].txt
# ✅ Processed and cleaned: [721215902091182170].txt
# ✅ Processed and cleaned: [724681893869518903] [part 10].txt
# ✅ Processed and cleaned: [724681893869518903] [part 2].txt
# ✅ Processed and cleaned: [724681893869518903] [part 3].txt
# ✅ Processed and cleaned: [724681893869518903] [part 4].txt
# ✅ Processed and cleaned: [724681893869518903] [part 5].txt
# ✅ Processed and cleaned: [724681893869518903] [part 6].txt
# ✅ Processed and cleaned: [724681893869518903] [part 7].txt
# ✅ Processed and cleaned: [724681893869518903] [part 8].txt
# ✅ Processed and cleaned: [724681893869518903] [part 9].txt
# ✅ Processed and cleaned: [724681893869518903].txt
# ✅ Processed and cleaned: [725104269673365574] [part 10].txt
# ✅ Processed and cleaned: [725104269673365574] [part 11].txt
# ✅ Processed and cleaned: [725104269673365574] [part 12].txt
# ✅ Processed and cleaned: [725104269673365574] [part 13].txt
# ✅ Processed and cleaned: [725104269673365574] [part 14].txt
# ✅ Processed and cleaned: [725104269673365574] [part 15].txt
# ✅ Processed and cleaned: [725104269673365574] [part 2].txt
# ✅ Processed and cleaned: [725104269673365574] [part 3].txt
# ✅ Processed and cleaned: [725104269673365574] [part 4].txt
# ✅ Processed and cleaned: [725104269673365574] [part 5].txt
# ✅ Processed and cleaned: [725104269673365574] [part 6].txt
# ✅ Processed and cleaned: [725104269673365574] [part 7].txt
# ✅ Processed and cleaned: [725104269673365574] [part 8].txt
# ✅ Processed and cleaned: [725104269673365574] [part 9].txt
# ✅ Processed and cleaned: [725104269673365574].txt
# ✅ Processed and cleaned: [727535866427211796] [part 10].txt
# ✅ Processed and cleaned: [727535866427211796] [part 11].txt
# ✅ Processed and cleaned: [727535866427211796] [part 12].txt
# ✅ Processed and cleaned: [727535866427211796] [part 13].txt
# ✅ Processed and cleaned: [727535866427211796] [part 14].txt
# ✅ Processed and cleaned: [727535866427211796] [part 15].txt
# ✅ Processed and cleaned: [727535866427211796] [part 16].txt
# ✅ Processed and cleaned: [727535866427211796] [part 17].txt
# ✅ Processed and cleaned: [727535866427211796] [part 18].txt
# ✅ Processed and cleaned: [727535866427211796] [part 19].txt
# ✅ Processed and cleaned: [727535866427211796] [part 20].txt
# ✅ Processed and cleaned: [727535866427211796] [part 21].txt
# ✅ Processed and cleaned: [727535866427211796] [part 2].txt
# ✅ Processed and cleaned: [727535866427211796] [part 3].txt
# ✅ Processed and cleaned: [727535866427211796] [part 4].txt
# ✅ Processed and cleaned: [727535866427211796] [part 5].txt
# ✅ Processed and cleaned: [727535866427211796] [part 6].txt
# ✅ Processed and cleaned: [727535866427211796] [part 7].txt
# ✅ Processed and cleaned: [727535866427211796] [part 8].txt
# ✅ Processed and cleaned: [727535866427211796] [part 9].txt
# ✅ Processed and cleaned: [727535866427211796].txt
# ✅ Processed and cleaned: [729289022727520307] [part 2].txt
# ✅ Processed and cleaned: [729289022727520307] [part 3].txt
# ✅ Processed and cleaned: [729289022727520307] [part 4].txt
# ✅ Processed and cleaned: [729289022727520307] [part 5].txt
# ✅ Processed and cleaned: [729289022727520307] [part 6].txt
# ✅ Processed and cleaned: [729289022727520307] [part 7].txt
# ✅ Processed and cleaned: [729289022727520307] [part 8].txt
# ✅ Processed and cleaned: [729289022727520307] [part 9].txt
# ✅ Processed and cleaned: [729289022727520307].txt
# ✅ Processed and cleaned: [729434177384087653].txt
# ✅ Processed and cleaned: [731254148678549595] [part 10].txt
# ✅ Processed and cleaned: [731254148678549595] [part 11].txt
# ✅ Processed and cleaned: [731254148678549595] [part 12].txt
# ✅ Processed and cleaned: [731254148678549595] [part 13].txt
# ✅ Processed and cleaned: [731254148678549595] [part 14].txt
# ✅ Processed and cleaned: [731254148678549595] [part 15].txt
# ✅ Processed and cleaned: [731254148678549595] [part 16].txt
# ✅ Processed and cleaned: [731254148678549595] [part 17].txt
# ✅ Processed and cleaned: [731254148678549595] [part 18].txt
# ✅ Processed and cleaned: [731254148678549595] [part 19].txt
# ✅ Processed and cleaned: [731254148678549595] [part 20].txt
# ✅ Processed and cleaned: [731254148678549595] [part 21].txt
# ✅ Processed and cleaned: [731254148678549595] [part 22].txt
# ✅ Processed and cleaned: [731254148678549595] [part 23].txt
# ✅ Processed and cleaned: [731254148678549595] [part 24].txt
# ✅ Processed and cleaned: [731254148678549595] [part 25].txt
# ✅ Processed and cleaned: [731254148678549595] [part 26].txt
# ✅ Processed and cleaned: [731254148678549595] [part 2].txt
# ✅ Processed and cleaned: [731254148678549595] [part 3].txt
# ✅ Processed and cleaned: [731254148678549595] [part 4].txt
# ✅ Processed and cleaned: [731254148678549595] [part 5].txt
# ✅ Processed and cleaned: [731254148678549595] [part 6].txt
# ✅ Processed and cleaned: [731254148678549595] [part 7].txt
# ✅ Processed and cleaned: [731254148678549595] [part 8].txt
# ✅ Processed and cleaned: [731254148678549595] [part 9].txt
# ✅ Processed and cleaned: [731254148678549595].txt
# ✅ Processed and cleaned: [732617988649386055] [part 10].txt
# ✅ Processed and cleaned: [732617988649386055] [part 2].txt
# ✅ Processed and cleaned: [732617988649386055] [part 3].txt
# ✅ Processed and cleaned: [732617988649386055] [part 4].txt
# ✅ Processed and cleaned: [732617988649386055] [part 5].txt
# ✅ Processed and cleaned: [732617988649386055] [part 6].txt
# ✅ Processed and cleaned: [732617988649386055] [part 7].txt
# ✅ Processed and cleaned: [732617988649386055] [part 8].txt
# ✅ Processed and cleaned: [732617988649386055] [part 9].txt
# ✅ Processed and cleaned: [732617988649386055].txt
# ✅ Processed and cleaned: [732979079103381565] [part 2].txt
# ✅ Processed and cleaned: [732979079103381565] [part 3].txt
# ✅ Processed and cleaned: [732979079103381565] [part 4].txt
# ✅ Processed and cleaned: [732979079103381565] [part 5].txt
# ✅ Processed and cleaned: [732979079103381565].txt
# ✅ Processed and cleaned: [733820409262243960].txt
# ✅ Processed and cleaned: [739107837036331040] [part 10].txt
# ✅ Processed and cleaned: [739107837036331040] [part 2].txt
# ✅ Processed and cleaned: [739107837036331040] [part 3].txt
# ✅ Processed and cleaned: [739107837036331040] [part 4].txt
# ✅ Processed and cleaned: [739107837036331040] [part 5].txt
# ✅ Processed and cleaned: [739107837036331040] [part 6].txt
# ✅ Processed and cleaned: [739107837036331040] [part 7].txt
# ✅ Processed and cleaned: [739107837036331040] [part 8].txt
# ✅ Processed and cleaned: [739107837036331040] [part 9].txt
# ✅ Processed and cleaned: [739107837036331040].txt
# ✅ Processed and cleaned: [749086673517674516] [part 2].txt
# ✅ Processed and cleaned: [749086673517674516] [part 3].txt
# ✅ Processed and cleaned: [749086673517674516] [part 4].txt
# ✅ Processed and cleaned: [749086673517674516] [part 5].txt
# ✅ Processed and cleaned: [749086673517674516].txt
# ✅ Processed and cleaned: [749894567154941962] [part 2].txt
# ✅ Processed and cleaned: [749894567154941962] [part 3].txt
# ✅ Processed and cleaned: [749894567154941962].txt
# ✅ Processed and cleaned: [750956484111892510] [part 2].txt
# ✅ Processed and cleaned: [750956484111892510] [part 3].txt
# ✅ Processed and cleaned: [750956484111892510].txt
# ✅ Processed and cleaned: [757019419087077397].txt
# ✅ Processed and cleaned: [761678882570633259] [part 2].txt
# ✅ Processed and cleaned: [761678882570633259] [part 3].txt
# ✅ Processed and cleaned: [761678882570633259] [part 4].txt
# ✅ Processed and cleaned: [761678882570633259] [part 5].txt
# ✅ Processed and cleaned: [761678882570633259] [part 6].txt
# ✅ Processed and cleaned: [761678882570633259] [part 7].txt
# ✅ Processed and cleaned: [761678882570633259] [part 8].txt
# ✅ Processed and cleaned: [761678882570633259].txt
# ✅ Processed and cleaned: [770626978679226378] [part 2].txt
# ✅ Processed and cleaned: [770626978679226378] [part 3].txt
# ✅ Processed and cleaned: [770626978679226378] [part 4].txt
# ✅ Processed and cleaned: [770626978679226378].txt
# ✅ Processed and cleaned: [770695931514847259].txt
# ✅ Processed and cleaned: [780553847276961812] [part 10].txt
# ✅ Processed and cleaned: [780553847276961812] [part 2].txt
# ✅ Processed and cleaned: [780553847276961812] [part 3].txt
# ✅ Processed and cleaned: [780553847276961812] [part 4].txt
# ✅ Processed and cleaned: [780553847276961812] [part 5].txt
# ✅ Processed and cleaned: [780553847276961812] [part 6].txt
# ✅ Processed and cleaned: [780553847276961812] [part 7].txt
# ✅ Processed and cleaned: [780553847276961812] [part 8].txt
# ✅ Processed and cleaned: [780553847276961812] [part 9].txt
# ✅ Processed and cleaned: [780553847276961812].txt
# ✅ Processed and cleaned: [781180833133625344] [part 2].txt
# ✅ Processed and cleaned: [781180833133625344] [part 3].txt
# ✅ Processed and cleaned: [781180833133625344] [part 4].txt
# ✅ Processed and cleaned: [781180833133625344] [part 5].txt
# ✅ Processed and cleaned: [781180833133625344].txt
# ✅ Processed and cleaned: [783794107083390996].txt
# ✅ Processed and cleaned: [783867661674217502].txt
# ✅ Processed and cleaned: [784383954425085992] [part 2].txt
# ✅ Processed and cleaned: [784383954425085992] [part 3].txt
# ✅ Processed and cleaned: [784383954425085992].txt
# ✅ Processed and cleaned: [790904542627758130].txt
# ✅ Processed and cleaned: [792868077413859348].txt
# ✅ Processed and cleaned: [794540887380066304].txt
# ✅ Processed and cleaned: [799476555524210688].txt
# ✅ Processed and cleaned: [800965685333327892] [part 2].txt
# ✅ Processed and cleaned: [800965685333327892] [part 3].txt
# ✅ Processed and cleaned: [800965685333327892] [part 4].txt
# ✅ Processed and cleaned: [800965685333327892].txt
# ✅ Processed and cleaned: [803664746104225812].txt
# ✅ Processed and cleaned: [805557554730106910].txt
# ✅ Processed and cleaned: [807381864854716476].txt
# ✅ Processed and cleaned: [807382101501935636].txt
# ✅ Processed and cleaned: [807382113623998524].txt
# ✅ Processed and cleaned: [807382297103302717].txt
# ✅ Processed and cleaned: [807382307328491540].txt
# ✅ Processed and cleaned: [807735380677230645].txt
# ✅ Processed and cleaned: [812542570721705994].txt
# ✅ Processed and cleaned: [818310036131938324].txt
# ✅ All files cleaned and saved in C:\Users\neelb\Desktop\MEDD8925 - Analyzing Data Quantitatively\MEDD8925 Discord Project\Cleaned Discord Data
